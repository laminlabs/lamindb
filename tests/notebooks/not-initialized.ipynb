# %%
import lamindb as ln
from lamindb.core._context import MissingTransformSettings
import pytest

with pytest.raises(MissingTransformSettings) as error:
    ln.track()

assert "To track this notebook, set" in error.exconly()
