# %% [markdown]
# A notebook without title.

# %%
import lamindb as ln
# Out:
# → connected lamindb: zethson/lamindb-unit-tests-core

# %%
# pass stem uid
ln.track("123456789ABC")
# Out:
# → created Transform('123456789ABC0000', key='no-title.ipynb'), started new Run('vy9H8tLSvZeF8CZS') at 2026-01-26 13:11:34 UTC
# → notebook imports: lamindb==2.0.1

# %%
assert ln.context.transform.description is None
assert ln.context.transform.key == "no-title.ipynb"
