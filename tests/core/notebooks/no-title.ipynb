# %% [markdown]
# A notebook without title.

# %%
import lamindb as ln
from lamindb.core._context import NoTitleError
import pytest

# %%
ln.track()

# %%
assert ln.context.transform.description == "no-title"
assert ln.context.transform.key == "no-title.ipynb"
