# %% [markdown]
# # Ingest assay results

# %%
import lamindb as ln

ln.nb.header()

# %% [markdown]
# `testuser1` just completed an experimental assay.

# %%
# !lndb login testuser1

# %% [markdown]
# Let's ingest an assay result table:

# %%
filepath = ln.datasets.schmidt22_crispra_gws_IFNG()
filepath

# %%
ingest = ln.db.Ingest()
ingest.add(filepath)
ingest.commit()
