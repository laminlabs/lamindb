# %% [markdown]
# # Introspect all tables

# %%
import lamindb as ln

ln.nb.header()

# %% [markdown]
# ## Data provenance

# %%
for entity in ln.schema.list_entities():
    if hasattr(ln.schema.core, entity):
        print(entity)
        display(getattr(ln.db.query, entity)().df())

# %% [markdown]
# ## Biological entities and wetlab

# %%
for entity in ln.schema.list_entities():
    if not hasattr(ln.schema.core, entity):
        print(entity)
        display(getattr(ln.db.query, entity)().df())

# %% [markdown]
# ## A few checks

# %%
assert (
    ln.db.query.dobject(name="Mouse Lymph Node scRNA-seq").one().checksum
    == "429aea8f43b6df5f7b2a8f95a1b6998b"
)
