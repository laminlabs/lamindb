# %% [markdown]
# # Ingest multiple datasets

# %%
from nbproject import header
from lamindb.do import ingest

header()
# Out:
# <table><tbody><tr><td style='text-align: left;'><b>id</b></td><td style='text-align: left;'>8Iih<span style='opacity:0.3'>xMbq9nhE</td></tr><tr><td style='text-align: left;'><b>time_init</b></td><td style='text-align: left;'>2022-07-15 11:14</td></tr><tr><td style='text-align: left;'><b>time_run</b></td><td style='text-align: left;'>2022-07-15 11:38</td></tr><tr><td style='text-align: left;'><b>version</b></td><td style='text-align: left;'>1</td></tr><tr><td style='text-align: left;'><b>dependency_store</b></td><td style='text-align: left;'>lamindb==0.0.9 nbproject==0.2.3 scanpy==1.8.2</td></tr><tr><td style='text-align: left;'><b>dependency_live</b></td><td style='text-align: left;'>lamindb==0.0.9 nbproject==0.2.3 scanpy==1.8.2</td></tr></tbody></table>

# %%
ingest.add("scanpy_pbmc68k_reduced.h5ad")
ingest.add("Visium10X_data_LI.h5ad")

# %%
ingest.status
# Out:
# {PosixPath('scanpy_pbmc68k_reduced.h5ad'): 'KZw1WCHIrgAIG5Lm4aOY',
#  PosixPath('Visium10X_data_LI.h5ad'): 'Oin5yQ6XELyUQyiGomti'}

# %%
ingest.commit(integrity=False, i_confirm_i_saved=True)
# Out:
# ℹ️ | Ingested the following files:
# | Ingested File                                      | Notebook                                  | User                               |
# |----------------------------------------------------+-------------------------------------------+------------------------------------|
# | scanpy_pbmc68k_reduced.h5ad (KZw1WCHIrgAIG5Lm4aOY) | 'Ingest multiple datasets' (8IihxMbq9nhE) | xiaoji.sun515@gmail.com (BjExb4ik) |
# | Visium10X_data_LI.h5ad (Oin5yQ6XELyUQyiGomti)      | 'Ingest multiple datasets' (8IihxMbq9nhE) | xiaoji.sun515@gmail.com (BjExb4ik) |
# ⚠️ | Consider using Jupyter Lab for ingesting data!
#     Interactive notebook integrity checks are currently only supported on Jupyter Lab.
#     Alternatively, manually save your notebook directly before calling `do.ingest.commit(..., integrity=True)`.
# ℹ️ | Bumped notebook version to 2. Wrote dependencies to dependency store.
# ℹ️ | File changed on disk! Reload and restart the notebook if you want to continue.
