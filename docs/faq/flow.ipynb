# %% [markdown]
# # Ingest flow cytometry data with cell markers

# %% [markdown]
# To read FCS files, see [readfcs](https://lamin.ai/docs/readfcs).

# %%
# !lndb load mydata

# %%
import lamindb as ln

ln.nb.header()

# %% [markdown]
# ## Flow cytometry data
#
#
# Here we load in a flow cytometry data which measures fluorescence parameters on each cell.

# %%
filepath = ln.dev.datasets.file_fcs()

filepath

# %% [markdown]
# ## Ingest with a "cell marker" reference

# %%
knowledge_table = ln.knowledge.CellMarker()

# %%
dobject = ln.record(filepath, features_ref=knowledge_table);

# %%
ln.add(dobject)
