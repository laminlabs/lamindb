# %% [markdown]
# # Can I ingest the same file twice?

# %% [markdown]
# Yes. But you'll get a warning if a data object with the same hash exists already.

# %%
# !lndb load mydata

# %%
import lamindb as ln
import pytest

ln.nb.header()

# %%
ln.settings.instance

# %% [markdown]
# This file already got ingested in a previous notebook.

# %%
filepath = ln.dev.datasets.file_fcs()

# %%
dobject = ln.DObject(filepath)
