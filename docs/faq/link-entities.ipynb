# %% [markdown]
# # Link entities

# %%
# !lndb load mydata

# %%
import lamindb as ln
import lamindb.schema as lns

ln.nb.header()

# %% [markdown]
# Link `dobject` and `biometa` via `dobject_biometa`

# %%
dobject = lns.DObject()
biometa = lns.wetlab.Biometa()

# %%
dobject, biometa

# %%
ln.link(dobject, biometa, add=False)

# %%
dobject1 = lns.DObject()
dobject2 = lns.DObject()
biometa = lns.wetlab.Biometa()

# %%
ln.link([dobject1, dobject2], biometa, add=False)

# %%
dtransform = lns.DTransform()
dobject = lns.DObject(dtransform_id=dtransform.id)

# %%
dtransform, dobject

# %%
ln.link(dtransform, dobject, add=False)
