# %% [markdown]
# # Link entities

# %%
# !lndb load mydata

# %%
import lamindb as ln

ln.nb.header()

# %% [markdown]
# Link `dobject` and `biometa` via `dobject_biometa`

# %%
dobject = ln.schema.core.dobject()
biometa = ln.schema.wetlab.biometa()

# %%
dobject, biometa

# %%
ln.link(dobject, biometa, add_link_entries=False)

# %%
dobject1 = ln.schema.core.dobject()
dobject2 = ln.schema.core.dobject()
biometa = ln.schema.wetlab.biometa()

# %%
ln.link([dobject1, dobject2], biometa, add_link_entries=False)

# %%
dtransform = ln.schema.core.dtransform()
dobject = ln.schema.core.dobject(dtransform_id=dtransform.id)

# %%
dtransform, dobject

# %%
ln.link(dtransform, dobject, add_link_entries=False)
