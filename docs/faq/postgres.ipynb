# %% [markdown]
# # Postgres

# %%
# !lndb init --storage mydata_postgres --schema bionty,wetlab,bfx --db postgresql://batman:robin@35.222.187.204:5432/movies

# %%
import lamindb as ln
import sklearn.datasets
import scanpy as sc
from lamindb.schema import core

ln.nb.header()

# %%
dobject = (
    ln.select(core.DObject)
    .where(core.DObject.checksum == "r4tnqmKI_SjrkdLzpuWp4g")
    .one_or_none()
)

# %%
dobject

# %%
if dobject is not None:
    usage = ln.select(core.usage).where(core.usage.dobject_id == dobject.id).one()
    with ln.session() as session:
        session.delete(usage)
        session.commit()
        session.delete(dobject)
        session.commit()

# %%
paradisi = ln.dev.datasets.file_jpg_paradisi05()

# %%
ingest = ln.Ingest()
ingest.add(paradisi);

# %%
ingest.commit()
