# %% [markdown]
# # R&D simulation: Track and analyze experimental data

# %%
import lamindb as ln

ln.nb.header()

# %% [markdown]
# This notebook is generated by test-user2.

# %%
# !lndb login test-user2

# %% [markdown]
# Let's check what experiments the test-user1 has registered:

# %%
experiments = ln.db.query.experiment(project_id=1, return_df=True)
experiments
